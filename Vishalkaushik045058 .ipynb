# %% [markdown]
# >[Fashion Segmentation through K-Means Clustering](#scrollTo=u_UsznX206x6)
#
# >[Objective](#scrollTo=o77zhiJ5Czvh)
#
# >[DESCRIPTION OF DATASET](#scrollTo=bEXY0HVqEEmL)
#
# >[Description of Data](#scrollTo=Hfytm0Mv2KuP)
#
# >>[2.1. Data Source, Size, Shape](#scrollTo=Hfytm0Mv2KuP)
#
# >>[2.2 Description of Variables](#scrollTo=Hfytm0Mv2KuP)
#
# >>>[2.3. Descriptive Statistics](#scrollTo=MRbyY4-qRylW)
#
# >>>>[2.3.1. Descriptive Statistics: Categorical Variables or Features](#scrollTo=MRbyY4-qRylW)
#
# >>>>>[2.3.1.1. Count | Frequency Statistics](#scrollTo=MRbyY4-qRylW)
#
# >>>>>[2.3.1.2. Proportion (Relative Frequency) Statistics](#scrollTo=MRbyY4-qRylW)
#
# >>>>[2.3.2. Descriptive Statistics: Non-Categorical Variables or Features](#scrollTo=MRbyY4-qRylW)
#
# >>>>>[2.3.2.1. Measures of Central Tendency](#scrollTo=MRbyY4-qRylW)
#
# >>>>>[2.3.2.2. Measures of Dispersion](#scrollTo=MRbyY4-qRylW)
#
# >>>>>[2.3.2.3. Correlation Statistics (with Test of Correlation)](#scrollTo=MRbyY4-qRylW)
#
# >>>>[Additional Information](#scrollTo=MRbyY4-qRylW)
#
# >[ANALYSIS OF DATA](#scrollTo=TflOiTjBEJBQ)
#
# >>[3.1. Data Pre-Processing](#scrollTo=TflOiTjBEJBQ)
#
# >>>[3.1.1. Missing Data Statistics and Treatment](#scrollTo=TflOiTjBEJBQ)
#
# >>>>[3.1.1.1. Missing Data Statistics: Records](#scrollTo=TflOiTjBEJBQ)
#
# >>>>[3.1.1.2. Missing Data Treatment: Records](#scrollTo=TflOiTjBEJBQ)
#
# >>>>[3.1.1.2. Missing Data Statistics: Categorical Variables or Features](#scrollTo=TflOiTjBEJBQ)
#
# >>>>[3.1.1.2. Missing Data Treatment: Categorical Variables or Features](#scrollTo=TflOiTjBEJBQ)
#
# >>>>[3.1.1.3. Missing Data Statistics: Non-Categorical Variables or Features](#scrollTo=TflOiTjBEJBQ)
#
# >>>>[3.1.1.3. Missing Data Treatment: Non-Categorical Variables or Features](#scrollTo=TflOiTjBEJBQ)
#
# >>>[3.1.2. Numerical Encoding of Categorical Variables or Features](#scrollTo=TflOiTjBEJBQ)
#
# >>>[3.1.3. Outlier Statistics and Treatment](#scrollTo=TflOiTjBEJBQ)
#
# >>>[3.1.4. Data Transformation and Scaling](#scrollTo=TflOiTjBEJBQ)
#
# >>>[3.1.5. Pre-Processed Dataset](#scrollTo=TflOiTjBEJBQ)
#
# >>>[Note:](#scrollTo=TflOiTjBEJBQ)
#
# >>[3.2 Data Analysis](#scrollTo=5R1UM5WZLEMc)
#
# >[Result / Managerial Implications](#scrollTo=IM0Um9iMHHPr)

# %% [markdown]
# # **Fashion Segmentation through K-Means Clustering**

# %% [markdown]
# #Objective
#
# 1. **Price analysis:** Businesses can use the data to track price fluctuations of specific products or entire categories over time. This can help them develop competitive pricing strategies and optimize their own product pricing.
#
# 2. **Product research and development:** By analyzing product features, types, and brands, companies can gain insights into what kind of products are popular and identify potential gaps in the market. This information can inform product development and marketing strategies.
#
# 3. **Recommendation systems:**  E-commerce platforms can leverage datasets like this to build recommendation systems that suggest relevant products to users based on their past purchases or browsing history.
#
# 4. **Market research:** Researchers can analyze the data to understand consumer trends, identify popular brands and product categories, and gauge market demand for specific types of products.
#
# 5. **Machine learning applications:** The data can be used to train machine learning models for various tasks, such as product classification, sentiment analysis of customer reviews, or predicting future demand for specific products.

# %% [markdown]
# # DESCRIPTION OF DATASET
#
# * product_id: A unique identifier for each product
# * brand_name: The name of the brand that makes the product
# * title: The name of the product
# * current_price: The current price of the product in USD
# * previous_price: The previous price of the product in USD (if available)
# * Gender: The gender that the product is targeted towards (M for Men)
# * currency: The currency that the price is listed in (USD)
# * rrp: The recommended retail price of the product (possibly in USD)
# * productCode: A unique code for the product
# * productType: The type of product (e.g. Product, Trainer)

# %% [markdown]
# # 2. **Description of Data**
#
# ##2.1. Data Source, Size, Shape
#
# 	### 2.1.1. Data Source (https://www.kaggle.com/)
#
# 	### 2.1.2. Data Size (2.85 MB)
#
# 	### 2.1.3. Data Shape (Dimension: Number of Variables-10 | Number of Records-61201 rows × 10 columns)
#
#
# ## 2.2 **Description of Variables**
#
# 1. Index Variable(s)
# - **Description**: Index variables serve as unique identifiers for each observation in the dataset. They are crucial for referencing and managing data but may not directly contribute to analysis.
#  product_id
#
# 2. Categorical Variables with Nominal Categories
# - **Description**: These variables represent categories without any inherent order or ranking. They are typically labels or groupings.
#   - **Brand Name**: Represents the manufacturer or brand of the product.
#   - **Gender**: Indicates the target gender for which the product is intended.
#   - **Currency**: Denotes the currency used for pricing.
#   - **Product Type**: Specifies the category or type of the product.
#
# 3. Non-Categorical Variables
# - **Description**: Non-categorical variables are numeric or continuous and do not fall into categorical or ordinal categories.
#   - **Current Price**: The current price of the product.
#   - **Previous Price**: The previous price of the product.
#   - **Recommended Retail Price (RRP)**: The manufacturer's suggested retail price for the product.

# %% [markdown]
# ### 2.3. Descriptive Statistics
#
# #### 2.3.1. Descriptive Statistics: Categorical Variables or Features
#
# ##### 2.3.1.1. Count | Frequency Statistics
# - **product_id**: 61200 non-null entries
# - **brand_name**: 61200 non-null entries
# - **title**: 61200 non-null entries
# - **Gender**: 61200 non-null entries
# - **currency**: 61200 non-null entries
# - **productType**: 61200 non-null entries
#
# ##### 2.3.1.2. Proportion (Relative Frequency) Statistics
# - No proportions provided as these are nominal categorical variables.
#
# #### 2.3.2. Descriptive Statistics: Non-Categorical Variables or Features
#
# ##### 2.3.2.1. Measures of Central Tendency
# - **current_price**:
#   - Mean: 50.639433
#   - Median (50th percentile): 41.690000
# - **previous_price**:
#   - Mean: 51.095332
#   - Median (50th percentile): 44.210000
# - **rrp**:
#   - Mean: 94.259919
#   - Median (50th percentile): 78.000000
#
# ##### 2.3.2.2. Measures of Dispersion
# - **current_price**:
#   - Standard Deviation: 42.409025
#   - Min: 2.610000
#   - Max: 237.000000
# - **previous_price**:
#   - Standard Deviation: 35.690232
#   - Min: 6.320000
#   - Max: 165.810000
# - **rrp**:
#   - Standard Deviation: 68.221765
#   - Min: 8.690000
#   - Max: 372.000000
#
# ##### 2.3.2.3. Correlation Statistics (with Test of Correlation)
# - Correlation between variables not provided in this report.
#
# #### Additional Information
# - **Memory Usage**: 4.7+ MB
# - **Non-null Counts**:
#   - product_id: 61200
#   - brand_name: 61200
#   - title: 61200
#   - current_price: 61200
#   - previous_price: 25280
#   - Gender: 61200
#   - currency: 61200
#   - rrp: 43326
#   - productCode: 61200
#   - productType: 61200

# %% [markdown]
# # ANALYSIS OF DATA
#
# ## 3.1. Data Pre-Processing
#
# ### 3.1.1. Missing Data Statistics and Treatment
#
# #### 3.1.1.1. Missing Data Statistics: Records
# - **Variable-wise Missing Data Information**:
#   - No missing data in any variable.
#
# #### 3.1.1.2. Missing Data Treatment: Records
#
# - **Removal of Records with More Than 50% Missing Data**: None
#
# #### 3.1.1.2. Missing Data Statistics: Categorical Variables or Features
#
# - No missing data in categorical variables.
#
# #### 3.1.1.2. Missing Data Treatment: Categorical Variables or Features
#
# - **Removal of Variables or Features with More Than 50% Missing Data**: None
# - **Imputation of Missing Data using Descriptive Statistics**: Mode (for categorical variables)
#
# #### 3.1.1.3. Missing Data Statistics: Non-Categorical Variables or Features
#
# - **previous_price**: 35920 missing values
# - **rrp (Recommended Retail Price)**: 17874 missing values
#
# #### 3.1.1.3. Missing Data Treatment: Non-Categorical Variables or Features
#
# - **Removal of Variables or Features with More Than 50% Missing Data**: None
# - **Imputation of Missing Data using Descriptive Statistics**: Mean or Median (for non-categorical variables)
#
# ### 3.1.2. Numerical Encoding of Categorical Variables or Features
#
# 1. `df_cat = df[['Gender', 'productType','brand_name']]`: This line creates a new DataFrame `df_cat` containing only the columns 'Gender', 'productType', and 'brand_name' from the original DataFrame `df`. These columns are typically considered categorical because they represent categories or labels rather than numerical data. Categorical data can further be divided into nominal (categories without an inherent order) or ordinal (categories with a specific order).
#
# 2. `df_noncat = df[['current_price', 'rrp','previous_price']]`: Similarly, this line creates a new DataFrame `df_noncat` containing only the columns 'current_price', 'rrp', and 'previous_price'. These columns are numerical data representing prices, and thus are considered non-categorical.
#
# The comments `# Categorical Data [Nominal | Ordinal]` and `# Non-Categorical Data` provide a brief description of the type of data contained in each DataFrame. The comment suggests that the 'Gender', 'productType', and 'brand_name' columns may contain either nominal or ordinal categorical data, while the 'current_price', 'rrp', and 'previous_price' columns contain non-categorical data (i.e., numerical data).
#
# Overall, this code is simply splitting the original DataFrame into two separate DataFrames based on the type of data they contain, which can be useful for subsequent analysis or preprocessing tasks specific to each data type.
#
# ### 3.1.3. Outlier Statistics and Treatment
#
# Outlier Detection:
#
# - Identified outliers using boxplot visualization for numeric variables.
#
# Outlier Treatment:
#
# - Outliers treated by performing normalization using Min-Max Scaler.
#
# ### 3.1.4. Data Transformation and Scaling
#
# - **Normalization**: Min-Max Scaling applied to non-categorical variables to bring them within a common scale.
#
# ### 3.1.5. Pre-Processed Dataset
#
# - **Pre-Processed Categorical Data Subset**: Encoded categorical data using Ordinal Encoder.
# - **Pre-Processed Non-Categorical Data Subset**: Normalized non-categorical data using Min-Max Scaler.
# - **Pre-Processed Dataset**: Merged pre-processed categorical and non-categorical data subsets.
#
# ### Note:
#
# - No data bifurcation into training and testing sets was required as part of this analysis.

# %% [markdown]
# ## 3.2 Data Analysis
#
# **Cluster Profiles:**
#
# **Cluster 0:**
# - **Characteristics:**
#   - Associated with a high Chi-Square value for all variables, indicating a significant association with the cluster labels.
#   - All ANOVA p-values are extremely low, indicating significant differences in mean values of pricing variables (current_price, rrp, previous_price) compared to other clusters.
# - **Inferences:**
#   - This cluster likely represents products with distinct pricing strategies and characteristics compared to other clusters.
#   - Products in this cluster may be targeted towards specific genders, product types, or brands, leading to significant pricing variations.
#
# **Cluster 1:**
# - **Characteristics:**
#   - Similar to Cluster 0, associated with high Chi-Square values and low ANOVA p-values, indicating significant associations and differences in mean values of variables.
# - **Inferences:**
#   - Products in this cluster might have pricing dynamics and characteristics that are different from Cluster 0 but similar to Cluster 0 in terms of significant pricing variations.
#
# **Cluster 2:**
# - **Characteristics:**
#   - Shares similarities with Clusters 0 and 1 in terms of significant Chi-Square values and low ANOVA p-values.
# - **Inferences:**
#   - This cluster likely represents another distinct group of products with unique pricing strategies and characteristics compared to Clusters 0 and 1.
#
# **Cluster Analysis:**
# - **Silhouette Score for 3 clusters:** 0.587
#   - The silhouette score indicates that the clusters are reasonably well-separated and internally cohesive.
#   - A score closer to 1 suggests better clustering, indicating that the clusters are distinct from each other.
# - **Davies-Bouldin Index for 3 clusters:** 0.528
#   - The Davies-Bouldin index measures the average similarity between each cluster and its most similar cluster.
#   - A lower value suggests better clustering, indicating that the clusters are well-separated.
#
# **Overall Analysis:**
# - The K-Means clustering with 3 clusters yields reasonably well-separated clusters with distinct characteristics in terms of pricing dynamics and other variables.
# - Each cluster represents a different group of products with unique pricing strategies and characteristics.
# - The significant associations and differences observed through chi-square tests and ANOVA reinforce the distinctiveness of the clusters and suggest potential segmentation opportunities for marketing and pricing strategies.

# %% [markdown]
# # **4 Result / Managerial Implications**
#
# The fashion industry is highly dynamic and competitive, requiring businesses to leverage data-driven insights for strategic decision-making. In this report, we analyze a comprehensive dataset using advanced statistical techniques such as Chi-Square tests, ANOVA, and clustering algorithms to derive actionable insights for managerial implications.
#
# **Chi-Square Test of Independence:**
#
# The Chi-Square tests conducted on variables such as previous price, gender, product type, brand name, and cluster reveal significant associations among these factors. This indicates that they are not independent of each other. Therefore, managers should consider these associations when formulating pricing strategies, designing targeted marketing campaigns, and positioning brands within different customer clusters.
#
# **ANOVA Analysis:**
#
# The ANOVA results demonstrate substantial differences in current price, recommended retail price (RRP), and previous price across the identified clusters. These differences highlight the varying price sensitivities and preferences among customer segments. As a result, businesses can tailor pricing strategies, promotions, and discounts to each cluster's characteristics to maximize revenue and customer satisfaction.
#
# **Cluster Analysis:**
#
# The clustering algorithm yielded three distinct clusters with a Silhouette Score of 0.586 and a Davies-Bouldin Index of 0.528, indicating good clustering performance. This segmentation enables businesses to understand customer segments better, optimize inventory management, and develop targeted marketing strategies based on cluster preferences and behavior.
#
# **Managerial Implications:**
#
# 1. **Segment-Specific Strategies:** Develop targeted marketing campaigns, promotions, and product offerings tailored to each cluster's characteristics and preferences identified through clustering and ANOVA analysis.
#
# 2. **Dynamic Pricing:** Implement dynamic pricing strategies that take into account the significant differences in price-related variables across clusters, as revealed by ANOVA. This includes offering personalized discounts and promotions to maximize sales.
#
# 3. **Brand Positioning:** Leverage the associations between brand names and other variables (gender, product type, cluster) identified through Chi-Square tests for effective brand positioning and targeted marketing efforts.
#
# 4. **Continuous Monitoring:** Regularly monitor and analyze customer behavior within clusters to adapt strategies dynamically and stay competitive in the fast-paced fashion industry landscape.
#
# **Conclusion:**
#
# By leveraging advanced analytics and statistical techniques, businesses can gain valuable insights into customer behavior, preferences, and market trends. These insights enable informed decision-making, leading to enhanced customer satisfaction, increased sales, and sustainable business growth in the fashion industry.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df= pd.read_excel("dataset.xlsx")
df
# Out:
#        product_id         brand_name  \
# 0       204499665             Replay
# 1       203420859       Jack & Jones
# 2       204285229       Jack & Jones
# 3       202261918  Don't Think Twice
# 4       202191610  Another Influence
# ...           ...                ...
# 61195   203652134               Dune
# 61196   203778655               Dune
# 61197   203202947             NaaNaa
# 61198   204060148         Brave Soul
# 61199   204347411  French Connection
#
#                                                    title  current_price  \
# 0                                Replay t-shirt in white          72.00
# 1              Jack & Jones script logo t-shirt in white          17.00
# 2                   Jack & Jones logo polo in pale green          34.00
# 3                   DTT denim board shorts in light blue          31.00
# 4      Another Influence towelling shorts co-ord in m...          23.00
# ...                                                  ...            ...
# ...

# %%
df_cat = df[['Gender', 'productType','brand_name']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['current_price', 'rrp','previous_price']] # Non-Categorical Data

# %%
# Dataset Used : df

df.info() # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61200 entries, 0 to 61199
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      61200 non-null  int64
#  1   brand_name      61200 non-null  object
#  2   title           61200 non-null  object
#  3   current_price   61200 non-null  float64
#  4   previous_price  25280 non-null  float64
#  5   Gender          61200 non-null  object
#  6   currency        61200 non-null  object
#  7   rrp             43326 non-null  float64
#  8   productCode     61200 non-null  int64
#  9   productType     61200 non-null  object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 4.7+ MB
#          product_id  current_price  previous_price           rrp   productCode
# count  6.120000e+04   61200.000000    25280.000000  43326.000000  6.120000e+04
# mean   1.877206e+08      50.639433       51.095332     94.259919  1.125134e+08
# ...

# %%
# 1.2.1. Impute Missing Categorical Data [Nominal | Ordinal] using Descriptive Satatistics : Central Tendency (Mode)
# ------------------------------------------------------------------------------------------------------------------

# Dataset Used : df_cat

si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
print(df_cat_mdi)
df_cat_mdi.info()
# Out:
#       Gender      productType         brand_name
# 0          M          Product             Replay
# 1          M          Product       Jack & Jones
# 2          M          Product       Jack & Jones
# 3          M          Product  Don't Think Twice
# 4          M          Product  Another Influence
# ...      ...              ...                ...
# 61195      F          Product               Dune
# 61196      F          Product               Dune
# 61197      F          Product             NaaNaa
# 61198      F          Product         Brave Soul
# 61199      F  MixMatchProduct  French Connection
#
# [61200 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61200 entries, 0 to 61199
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       61200 non-null  object
#  1   productType  61200 non-null  object
#  2   brand_name   61200 non-null  object
# dtypes: object(3)
# ...

# %%
# 1.2.2.1. Impute Missing Non-Categorical Data using Descriptive Statistics : Central Tendency
# --------------------------------------------------------------------------------------------

# Dataset Used : df_noncat

si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
print(df_noncat_mdi_si)
df_noncat_mdi_si.info()
# Out:
#        current_price     rrp  previous_price
# 0              72.00  100.00       51.095332
# 1              17.00   21.00       51.095332
# 2              34.00   43.00       51.095332
# 3              31.00   42.00       51.095332
# 4              23.00   48.00       51.095332
# ...              ...     ...             ...
# 61195          53.69  108.96       66.320000
# 61196          47.37   91.59       58.430000
# 61197          48.00   78.00       51.095332
# 61198          27.00   53.00       51.095332
# 61199          31.00   51.00       51.095332
#
# [61200 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61200 entries, 0 to 61199
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   current_price   61200 non-null  float64
#  1   rrp             61200 non-null  float64
#  2   previous_price  61200 non-null  float64
# dtypes: float64(3)
# memory usage: 1.4 MB

# %%
# 2. Numeric Coding of Data
# -------------------------

# 2.1. Numeric Encoding of Categorical Data [Nominal & Ordinal]
# -------------------------------------------------------------

# Dataset Used : df_cat_mdt
df_cat_mdt_code = df_cat_mdi.copy()

# Using Scikit Learn : Ordinal Encoder (Superior)
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['Gender_code', 'productType_code','brand_name_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#       Gender      productType         brand_name  Gender_code  \
# 0          M          Product             Replay          1.0
# 1          M          Product       Jack & Jones          1.0
# 2          M          Product       Jack & Jones          1.0
# 3          M          Product  Don't Think Twice          1.0
# 4          M          Product  Another Influence          1.0
# ...      ...              ...                ...          ...
# 61195      F          Product               Dune          0.0
# 61196      F          Product               Dune          0.0
# 61197      F          Product             NaaNaa          0.0
# 61198      F          Product         Brave Soul          0.0
# 61199      F  MixMatchProduct  French Connection          0.0
#
#        productType_code  brand_name_code
# 0                   2.0             40.0
# 1                   2.0             24.0
# 2                   2.0             24.0
# 3                   2.0             13.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'Offers', 'Average Price', and 'Number of Ratings'
df_noncat = df[['current_price', 'rrp','previous_price']]

# Create vertical boxplot for 'current_price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['current_price'])
plt.title('Boxplot of current_price')
plt.ylabel('current_price')
plt.show()

# Create vertical boxplot for 'rrp'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['rrp'])
plt.title('Boxplot of rrp')
plt.ylabel('rrp')
plt.show()

# Create vertical boxplot for 'previous_price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['previous_price'])
plt.title('Boxplot of previous_price')
plt.ylabel('previous_price')
plt.show()

# %%
# 3. Data Transformation & Rescaling [Treatment of Outliers]
# ----------------------------------------------------------

# Dataset Used : df_noncat_mdt

# Scaling Variable : income

# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdi_si [['current_price', 'rrp','previous_price']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['current_price_mnorm', 'rrp_mnorm','previous_price_mnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
df_noncat_mdt_mmn = df_noncat_mdi_si.join(df_noncat_minmax_norm); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
#df_noncat_mdt_mmn = pd.merge(df_noncat_mdt, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#        current_price     rrp  previous_price  current_price_mnorm  rrp_mnorm  \
# 0              72.00  100.00       51.095332             0.296045   0.251328
# 1              17.00   21.00       51.095332             0.061393   0.033883
# 2              34.00   43.00       51.095332             0.133922   0.094437
# 3              31.00   42.00       51.095332             0.121123   0.091685
# 4              23.00   48.00       51.095332             0.086992   0.108200
# ...              ...     ...             ...                  ...        ...
# 61195          53.69  108.96       66.320000             0.217927   0.275990
# 61196          47.37   91.59       58.430000             0.190964   0.228180
# 61197          48.00   78.00       51.095332             0.193652   0.190774
# 61198          27.00   53.00       51.095332             0.104057   0.121962
# 61199          31.00   51.00       51.095332             0.121123   0.116457
#
#        previous_price_mnorm
# ...

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
# Out:
#       Gender      productType         brand_name  Gender_code  \
# 0          M          Product             Replay          1.0
# 1          M          Product       Jack & Jones          1.0
# 2          M          Product       Jack & Jones          1.0
# 3          M          Product  Don't Think Twice          1.0
# 4          M          Product  Another Influence          1.0
# ...      ...              ...                ...          ...
# 61195      F          Product               Dune          0.0
# 61196      F          Product               Dune          0.0
# 61197      F          Product             NaaNaa          0.0
# 61198      F          Product         Brave Soul          0.0
# 61199      F  MixMatchProduct  French Connection          0.0
#
#        productType_code  brand_name_code  current_price     rrp  \
# 0                   2.0             40.0          72.00  100.00
# 1                   2.0             24.0          17.00   21.00
# ...

# %%
#K-Means Clustering

# 2.1.1. Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia

'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
train_new_df=df_ppd[['Gender_code', 'productType_code','brand_name_code','current_price_mnorm', 'rrp_mnorm','previous_price_mnorm']]
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(train_new_df)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
plt.show()

km_2cluster = kmclus(n_clusters=2, init='random', random_state=222)
km_2cluster_model = km_2cluster.fit_predict(train_new_df)

km_3cluster = kmclus(n_clusters=3, init='random', random_state=333)
km_3cluster_model = km_3cluster.fit_predict(train_new_df)

km_4cluster = kmclus(n_clusters=4, init='random', random_state=333)
km_4cluster_model = km_4cluster.fit_predict(train_new_df)

sscore_km_2cluster = sscore(train_new_df, km_2cluster_model);
print(f"Silhouette Score for 2 clusters: {sscore_km_2cluster}")
dbscore_km_2cluster = dbscore(train_new_df, km_2cluster_model);
print(f"Davies-Bouldin Index for 2 clusters: {dbscore_km_2cluster}\n")
sscore_km_3cluster = sscore(train_new_df, km_3cluster_model)
print(f"Silhouette Score for 3 clusters: {sscore_km_3cluster}")
dbscore_km_3cluster = dbscore(train_new_df, km_3cluster_model)
print(f"Davies-Bouldin Index for 3 clusters: {dbscore_km_3cluster}\n")

sscore_km_4cluster = sscore(train_new_df, km_4cluster_model)
print(f"Silhouette Score for 4 clusters: {sscore_km_4cluster}")
dbscore_km_4cluster = dbscore(train_new_df, km_4cluster_model)
print(f"Davies-Bouldin Index for 4 clusters: {dbscore_km_4cluster}\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
import time
import psutil
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

train_new_df = df_ppd[['Gender_code', 'productType_code', 'brand_name_code', 'current_price', 'rrp', 'previous_price']]

# Start time
start_time = time.time()

# Specify the number of clusters
num_clusters = 3

# Initialize KMeans object
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

# Fit KMeans clustering model to the data
kmeans.fit(train_new_df[['current_price', 'rrp', 'previous_price', 'Gender_code', 'productType_code', 'brand_name_code']])

# End time
end_time = time.time()

# Total time taken
time_taken = end_time - start_time
print("Time taken by K-Means for k=4:", "{:.4f} seconds".format(time_taken))

# Memory used by the KMeans model
memory_used = psutil.Process().memory_info().rss / 1024 / 1024  # Memory in MB
print("Memory used by K-Means for k=4:", "{:.2f} MB".format(memory_used))

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to DataFrame
train_new_df['cluster'] = cluster_labels

# Get centroids of each cluster
centroids = kmeans.cluster_centers_

# Visualize the clusters using seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=train_new_df, x='rrp', y='current_price', hue='cluster', palette='viridis', s=100)
plt.scatter(centroids[:, 1], centroids[:, 0], marker='*', s=300, c='black', label='Centroids')  # Corrected centroids' coordinates
plt.xlabel('rrp')
plt.ylabel('current_price')
plt.title('K-means Clustering with Centroids')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Time taken by K-Means for k=4: 0.8136 seconds
# Memory used by K-Means for k=4: 337.26 MB
# <ipython-input-13-eb8fbb5d4b4f>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_new_df['cluster'] = cluster_labels

# %%
# Further analysis or visualization with cluster labels

# Cluster Analysis with Categorical Variables: Chi-Square Test of Independence
# Assuming you have performed clustering and added cluster labels to your DataFrame 'df'

import pandas as pd
from scipy.stats import chi2_contingency

# Select categorical variables for analysis
categorical_variables = ['previous_price', 'Gender_code', 'productType_code', 'brand_name_code', 'cluster']

# Create a contingency table for each categorical variable and the cluster labels
contingency_tables = {}
for variable in categorical_variables:
    contingency_tables[variable] = pd.crosstab(train_new_df[variable], train_new_df['cluster'])

# Perform Chi-Square Test of Independence for each contingency table
chi2_results = {}
for variable, contingency_table in contingency_tables.items():
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi2_results[variable] = {'Chi-Square': chi2, 'P-value': p}

# Display the results
for variable, result in chi2_results.items():
    print(f"Chi-Square Test of Independence for variable '{variable}':")
    print(f"   - Chi-Square Value: {result['Chi-Square']}")
    print(f"   - P-value: {result['P-value']}")
# Out:
# Chi-Square Test of Independence for variable 'previous_price':
#    - Chi-Square Value: 29952.148796106434
#    - P-value: 0.0
# Chi-Square Test of Independence for variable 'Gender_code':
#    - Chi-Square Value: 3950.4770406641865
#    - P-value: 0.0
# Chi-Square Test of Independence for variable 'productType_code':
#    - Chi-Square Value: 652.0859032353824
#    - P-value: 8.240433190973062e-140
# Chi-Square Test of Independence for variable 'brand_name_code':
#    - Chi-Square Value: 100715.66094220983
#    - P-value: 0.0
# Chi-Square Test of Independence for variable 'cluster':
#    - Chi-Square Value: 122399.99999999999
#    - P-value: 0.0

# %%
from scipy.stats import f_oneway

# List of features for ANOVA
features = ['current_price', 'rrp', 'previous_price']

# Initialize an empty dictionary to store ANOVA results
anova_results = {}

# Iterate over unique cluster labels
for cluster_label in train_new_df['cluster'].unique():
    # Filter dataframe for the current cluster
    cluster_df = train_new_df[train_new_df['cluster'] == cluster_label]

    # Initialize an empty dictionary to store ANOVA results for the current cluster
    cluster_anova_results = {}

    # Perform ANOVA for each feature
    for feature in features:
        # Perform ANOVA test
        anova_result = f_oneway(*[train_new_df[train_new_df['cluster'] == i][feature] for i in train_new_df['cluster'].unique()])
        # Store ANOVA result
        cluster_anova_results[feature] = anova_result

    # Store ANOVA results for the current cluster
    anova_results[cluster_label] = cluster_anova_results

# Print ANOVA results
for cluster_label, cluster_anova_result in anova_results.items():
    print(f"Cluster {cluster_label} ANOVA Results:")
    for feature, result in cluster_anova_result.items():
        print(f"{feature}: F-value = {result.statistic}, p-value = {result.pvalue}")
# Out:
# Cluster 0 ANOVA Results:
# current_price: F-value = 158286.77644811966, p-value = 0.0
# rrp: F-value = 99538.15870132521, p-value = 0.0
# previous_price: F-value = 12233.056294106458, p-value = 0.0
# Cluster 1 ANOVA Results:
# current_price: F-value = 158286.77644811966, p-value = 0.0
# rrp: F-value = 99538.15870132521, p-value = 0.0
# previous_price: F-value = 12233.056294106458, p-value = 0.0
# Cluster 2 ANOVA Results:
# current_price: F-value = 158286.77644811966, p-value = 0.0
# rrp: F-value = 99538.15870132521, p-value = 0.0
# previous_price: F-value = 12233.056294106458, p-value = 0.0

# %%
# Plot paired plots for each variable
sns.pairplot(train_new_df, hue='cluster', palette='viridis')
plt.show()

# %%
plt.figure(figsize=(30,45))
for i, col in enumerate(df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(9, 2, i+1)
        sns.kdeplot(df[col], ax=ax)
        plt.xlabel(col)

plt.show()
